# %%
import random
print ("Numero: ",random.randint(1, 25))
# Out:
# Numero:  22

# %%
nombre = input("ingrese su nombre: ")
if nombre.isupper():
    print("nombre valido")
else:
    print("mal chamu: hagalo en mayucula")

peso = (input("ingrese su peso en kg: "))
if peso.isdigit():
    peso = int(peso)
    print("peso valido:, peso")
else:
    print("mal otra ve chamu: ponga el numero en entero")
# Out:
# mal chamu: hagalo en mayucula
# mal otra ve chamu: ponga el numero en entero
