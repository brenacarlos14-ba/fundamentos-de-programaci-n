# %% [markdown]
# # EJERCICIOS NORMALES

# %% [markdown]
# ## EXTRA 1

# %%
calificaciones = (7.5, 9.0, 8.0, 6.5, 10.0)

print("la tercera clificación es: ", calificaciones[2])

calif5 = float(input("introduce tu numero: "))
calif6 = float(input("pon tu numero bro: "))

nuevas_calificaciones = calificaciones + (calif5, calif6)

lista_calif = list(nuevas_calificaciones)

lista_calif.sort(reverse=True)
print("mayor a menor: ", lista_calif)

def calcular_suma(elementos):
    return sum(elementos)

print("nueva tupla", nuevas_calificaciones)
print("resultado: ", calcular_suma(lista_calif))
# Out:
# la tercera clificación es:  8.0
# mayor a menor:  [10.0, 9.5, 9.0, 8.5, 8.0, 7.5, 6.5]
# nueva tupla (7.5, 9.0, 8.0, 6.5, 10.0, 8.5, 9.5)
# resultado:  59.0

# %% [markdown]
# ## EXTRA 2

# %%
contactos = {
    "ana": "555-0101",
    "luis": "555-0102",
    "mia": "555-0103"
}

nombre = input("ingresa el nombre: ")
telefono = input("ingresa el telefono: ")

contactos[nombre]=telefono

print(" ".join(contactos.keys()))

def hola(name):
    return contactos.get(name, "buscalo bien")

nombrenombrado = input("encuentra el nombre: ")
celefono = hola(nombre)

print(f"telefono en {nombrenombrado}: {celefono} ")
# Out:
# ana luis mia pedro
# telefono en pedro: 852963.62

# %% [markdown]
# ## EXTRA 3

# %%
while True:
    try:
        numero1 = float(input("ingresa el numero1: "))
        numero2 = float(input("pon el numero 2porfa: "))
        resultado = numero1/numero2
        print("el resultado es: ",resultado)

    except ZeroDivisionError:
        print("error no seas malo")
        
    break
# Out:
# el resultado es:  4.0

# %% [markdown]
# ## EXTRA 4

# %%
mensaje = "Python es un lenguaje poderoso"

print("Longitud:", len(mensaje))

print("Mayúsculas:", mensaje.upper())

nuevo_mensaje = mensaje.replace("Python", "programación")
print("Reemplazado:", nuevo_mensaje)

def contar_palabras(texto):
    palabras = texto.split()
    return len(palabras)

print("Número de palabras:", contar_palabras(mensaje))
# Out:
# Longitud: 30
# Mayúsculas: PYTHON ES UN LENGUAJE PODEROSO
# Reemplazado: programación es un lenguaje poderoso
# Número de palabras: 5

# %% [markdown]
# # EJERCICIOS CASTIGADOS

# %% [markdown]
# ## EXTRA 1 CASTIGO

# %%
espera = ("maria", "jose", "carlos", "lucia", "pedro")

print(espera[2])

stop5 = input("introduce tu name: ")
stop6 = input("pontunombre bro: ")
nuevos_nombres = espera + (stop5, stop6)

lista_ordenada = list(nuevos_nombres)
lista_ordenada.sort() 

print(lista_ordenada)
print(len(lista_ordenada))
# Out:
# carlos
# ['carlos', 'hola', 'jose', 'lucia', 'maria', 'miogol', 'pedro']
# 7

# %% [markdown]
# ## EXTRA 2 CASTIGO

# %%
candidatos = {
    "A":0, 
    "B":0, 
    "C":0
    }

cantidad = int(input("¿cuantos votos van a ser?"))
conteo = 1

while conteo <= cantidad:
    voto = input(f"ingresa el voto {conteo} (A, B o C): ")
    if voto.upper() in candidatos:
        print(f"voto es valido para {voto.upper()}")
        candidatos[voto.upper()]+= 1
        conteo += 1
    else:
        print("el voto no es valido, otra vez")

print("\nResultados: ")
for k, v in candidatos.items():
    print(f"opción {k}, votos:{v} ")

print(f"\nNumero de votos: {cantidad}")
# Out:
# voto es valido para A
# voto es valido para A
# voto es valido para A
#
# Resultados:
# opción A, votos:3
# opción B, votos:0
# opción C, votos:0
#
# Numero de votos: 3

# %% [markdown]
# ## EXTRA 3 CASTIGO

# %%
while True:
    try:
        numero1 = float(input("ingresa el numero1: "))
        numero2 = float(input("pon el numero 2porfa: "))
        resultado = numero1/numero2
        print("el resultado es: ",resultado)
    except ZeroDivisionError:
        print("error no seas malo")
    break
# Out:
# el resultado es:  9.0

# %% [markdown]
# ## EXTRA 4 CASTIGO

# %%
def contadordepalabras(frase):
    palabras = frase.split()
    return len(palabras)

frasechad = input("Introduce una frase: ")

print(f"longitud de la frase: {len(frasechad)}")
print(f"mayúsculas: {frasechad.upper()}")

frase_modificada = frasechad.replace("python", "programación")
print(f"frase modificada: {frase_modificada}")

total_palabras = contadordepalabras(frasechad)
print(f"número de palabras usadas: {total_palabras}")
# Out:
# longitud de la frase: 22
# mayúsculas: HOLA MI HERMOSA PYTHON
# frase modificada: hola mi hermosa programación
# número de palabras usadas: 4

# %% [markdown]
# ## EXTRA 5 CASTIGO

# %%
def op1(): print(f"Ordenada: {tuple(sorted((45, 12, 89, 3, 27)))}")

def op2():
    c = {"ana": "555-1234", "carlos": "555-5678", "sofía": "555-9012"}
    n = input("Nombre: ").capitalize()
    print(f"teléfono: {c[n]}" if n in c else "No encontrado.")

def op3():
    try:
        print(f"Resultado: {float(input('Num 1: ')) / float(input('Num 2: '))}")
    except ZeroDivisionError: print("Error: División entre cero.")
    except ValueError: print("Error: Entrada no válida.")

def op4():
    t = input("Texto: ")
    print(f"Caracteres: {len(t)} | Palabras: {len(t.split())}")

while True:
    print("\n1.Tupla | 2.Contacto | 3.Dividir | 4.Texto | 5.Salir")
    op = input("Opción: ")
    if op == "1": op1()
    elif op == "2": op2()
    elif op == "3": op3()
    elif op == "4": op4()
    elif op == "5": print("Adiós."); break
    else: print("cintas error.")
# Out:
# 1.Tupla | 2.Contacto | 3.Dividir | 4.Texto | 5.Salir
# Opción inválida.
#
# 1.Tupla | 2.Contacto | 3.Dividir | 4.Texto | 5.Salir
# Opción inválida.
#
# 1.Tupla | 2.Contacto | 3.Dividir | 4.Texto | 5.Salir
# Opción inválida.
#
# 1.Tupla | 2.Contacto | 3.Dividir | 4.Texto | 5.Salir
# Opción inválida.
#
# 1.Tupla | 2.Contacto | 3.Dividir | 4.Texto | 5.Salir
# Opción inválida.
#
# 1.Tupla | 2.Contacto | 3.Dividir | 4.Texto | 5.Salir
# Opción inválida.
#
# 1.Tupla | 2.Contacto | 3.Dividir | 4.Texto | 5.Salir
# Opción inválida.
#
# 1.Tupla | 2.Contacto | 3.Dividir | 4.Texto | 5.Salir
# Opción inválida.
#
# 1.Tupla | 2.Contacto | 3.Dividir | 4.Texto | 5.Salir
# Opción inválida.
#
# 1.Tupla | 2.Contacto | 3.Dividir | 4.Texto | 5.Salir
# Opción inválida.
#
# 1.Tupla | 2.Contacto | 3.Dividir | 4.Texto | 5.Salir
# Opción inválida.
#
# 1.Tupla | 2.Contacto | 3.Dividir | 4.Texto | 5.Salir
# Opción inválida.
#
# 1.Tupla | 2.Contacto | 3.Dividir | 4.Texto | 5.Salir
# Opción inválida.
#
# ...
