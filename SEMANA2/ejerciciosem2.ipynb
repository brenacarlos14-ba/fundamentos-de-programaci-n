# %% [markdown]
# # EJERCICIOS DE SEMANA 2

# %%
calif = int(input("Ingrese calificación: "))
conducta = int(input("Ingrese calidad de conducta: "))

if calif >= 90:
    print("A")
    if conducta >= 9:
        print("Tu conducta es exelente")
elif calif >= 80:
    print("B")
elif calif >= 70:
    print("C")
elif calif >= 60:
    print("D")
else:
    print("E")
# Out:
# A
# Tu conducta es exelente

# %% [markdown]
# # OPERADORES LOGICOS

# %%
Pl1 = True
Pl2 = False

print(Pl1 and Pl2)
# Out:
# False

# %%
edad = 65
tipo = "adulto_mayor"

es_mayor = edad >= 18
print(es_mayor)
aplica_descuento = (edad >= 60) and (tipo == "adulto mayor")
print(aplica_descuento)
# Out:
# True
# False

# %%
edad = int(input("Ingresa tu edad"))

if not(edad < 0):
    print("Aguanta, no hay edades menores a cero")
else:
    print("Ahora si vamos a trabajar con edades reales")
# Out:
# Aguanta, no hay edades menores a cero

# %% [markdown]
# # Ejercicios

# %% [markdown]
# # ejercicio 1: mayor de edad

# %%
edad= int(input("edad del estudiante"))
if (0>18):
    print("es menor de edad")
else:
    print("es mayor de edad")
# Out:
# es mayor de edad

# %% [markdown]
# # ejercicio 2: numero par o impar

# %%
numero = int(input("Ingresa un numero entero"))
if (numero % 2 == 0 ):
    print("Es un numero par")
else:
    print("Es un número impar")
# Out:
# Es un número impar

# %% [markdown]
# # ejercicio 3: calificación aprobatoria

# %%
calificación= int(input("calificación del estudiante"))
if (calificación >= 6):
    print("es listo")
else:
    print("es tonto😔")
# Out:
# es listo

# %% [markdown]
# # ejercicio 4: calificación por rango de edad con elif

# %%
edad = int(input("Ingrese edad: "))

if edad <= 3:
    print("como escribiste")
elif edad <= 12:
    print("eres un pivito")
elif edad <= 17:
    print("eres un pive")
elif edad >=18:
    print("eres un adulto")
# Out:
# eres un pive

# %% [markdown]
# # ejericicio 5: descuento por tipo de visitante

# %%
boleto=int(input("Ingrese tipo de boleto: "))

if (boleto == "infantil"):
    precio_descuento = precio_boleto * ("-60, disfrute su estancia")
elif (boleto == "normal"):
    precio_descuento = precio_boleto * ("-67, disfrute su estancia")
elif (boleto == "adulto mayor"):
    precio_descuento = precio_boleto * ("-60, disfrute su estancia")
elif (boleto == "estudiantil"):
    precio_descuento = precio_boleto * ("-60, disfrute su estancia")
else:
    precio_descuento = precio_boleto * 1
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 boleto=int(input("Ingrese tipo de boleto: "))
#       2
#       3 if (boleto == "infantil"):
#       4     precio_descuento = precio_boleto * ("-60, disfrute su estancia")
#
# ValueError: invalid literal for int() with base 10: 'normal'
