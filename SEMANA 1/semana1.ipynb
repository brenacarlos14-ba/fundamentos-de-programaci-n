# %% [markdown]
# Variables
# ## variables de python son tipos de datos que tienen diferentes formas
# -numericas
#   -enteros
#   -flotante
# -cadenas de caracteres
# -booleanos
# -compuestos

# %%
nombre = "Carlos"
edad = "18"
es_estudiante = True
esta_activo = None
print(type(nombre))
print(type(edad))
print(type(es_estudiante))
print(type(esta_activo))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'bool'>
# <class 'NoneType'>

# %%
print(nombre)
print("hola", nombre, "ya vi que tienes", edad, "años de edad")
# Out:
# Carlos
# hola Carlos ya vi que tienes 18 años de edad
